# %% [markdown]
# ## Import Libraries

# %%
# !pip install spotipy
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 240.3/240.3 kB 1.1 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.5/62.5 kB 1.1 MB/s eta 0:00:0000:01
# ...
#   Using cached async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# ...
#
# [notice] A new release of pip is available: 23.0 -> 23.1.2
# [notice] To update, run: pip install --upgrade pip

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd

# %%
#add your keys here
client_credentials_manager = SpotifyClientCredentials(client_id="453c4860e19c4c7bb6304be91d980e6b", client_secret="ee1055d309d24cdbbf76694e65a595fb")

# %%
sp = spotipy.Spotify(client_credentials_manager = client_credentials_manager)

# %% [markdown]
# ## Top Songs-Global List

# %%
playlist_link = "https://open.spotify.com/playlist/37i9dQZEVXcQ9COmYvdajy"

# %%
https://open.spotify.com/playlist/37i9dQZEVXcQ9COmYvdajy

# %%
playlist_URI = playlist_link.split("/")[-1].split('?')[0]
print(playlist_URI)
# Out:
# 37i9dQZEVXcQ9COmYvdajy

# %%
data = sp.playlist('37i9dQZEVXcQ9COmYvdajy')

# %%
data.keys()
# Out:
# dict_keys(['collaborative', 'description', 'external_urls', 'followers', 'href', 'id', 'images', 'name', 'owner', 'primary_color', 'public', 'snapshot_id', 'tracks', 'type', 'uri'])

# %%
data['tracks'].keys()
# Out:
# dict_keys(['href', 'items', 'limit', 'next', 'offset', 'previous', 'total'])

# %%
len(data['tracks']['items'])
# Out:
# 30

# %%
data['tracks']['items'][0].keys()
# Out:
# dict_keys(['added_at', 'added_by', 'is_local', 'primary_color', 'track', 'video_thumbnail'])

# %%
data['tracks']['items'][0]['track']['name']
# Out:
# '365 (Thr33 6ix 5ive) - Harry Romero Remix'

# %%
data['tracks']['items']
# Out:
# [{'added_at': '2023-05-08T04:00:00Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_group': 'single',
#     'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1sl3gVNz3Nxd4poA8f76sl'},
#       'href': 'https://api.spotify.com/v1/artists/1sl3gVNz3Nxd4poA8f76sl',
#       'id': '1sl3gVNz3Nxd4poA8f76sl',
#       'name': 'HoneyLuv',
#       'type': 'artist',
#       'uri': 'spotify:artist:1sl3gVNz3Nxd4poA8f76sl'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/36AJmodiIrwV9U3QOiLMYM'},
#       'href': 'https://api.spotify.com/v1/artists/36AJmodiIrwV9U3QOiLMYM',
#       'id': '36AJmodiIrwV9U3QOiLMYM',
#       'name': 'Harry Romero',
#       'type': 'artist',
# ...

# %%
#Get full details of the tracks of a playlist:  playlist_tracks(playlist_id, fields=None, limit=100, offset=0, market=None, additional_types=('track', ))
data = sp.playlist_tracks(playlist_URI) 
print(data)
# Out:
# ---------------------------------------------------------------------------
# RemoteDisconnected                        Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/urllib3/connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
# ...

# %%
data['items']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 data['items']
#
# KeyError: 'items'

# %%
data['items'][0]['track']['album']['id']
# Out:
# '7aGzSSUD8S6IhPCsZSiuMT'

# %%
data['items'][0]['track']['album']['name']
# Out:
# 'un x100to'

# %%
data['items'][0]['track']['album']['release_date']
# Out:
# '2023-04-17'

# %%
data['items'][0]['track']['album']['total_tracks']
# Out:
# 1

# %%
data['items'][0]['track']['album']['external_urls']['spotify']
# Out:
# 'https://open.spotify.com/album/7aGzSSUD8S6IhPCsZSiuMT'

# %%
album_list = []
for row in data['items']:
    album_id = row['track']['album']['id']
    album_name = row['track']['album']['name']
    album_release_date = row['track']['album']['release_date']
    album_total_tracks = row['track']['album']['total_tracks']
    album_url = row['track']['album']['external_urls']['spotify']
    album_element = {'album_id':album_id,'name':album_name,'release_date':album_release_date,
                        'total_tracks':album_total_tracks,'url':album_url}
    album_list.append(album_element)

# %%
album_list
# Out:
# [{'album_id': '7aGzSSUD8S6IhPCsZSiuMT',
#   'name': 'un x100to',
#   'release_date': '2023-04-17',
#   'total_tracks': 1,
#   'url': 'https://open.spotify.com/album/7aGzSSUD8S6IhPCsZSiuMT'},
#  {'album_id': '5aDEezKnOqyQo0qvTFhpkM',
#   'name': 'DESVELADO',
#   'release_date': '2023-04-28',
#   'total_tracks': 16,
#   'url': 'https://open.spotify.com/album/5aDEezKnOqyQo0qvTFhpkM'},
#  {'album_id': '6aBVGuOUEuX18rHxyDWbti',
#   'name': 'La Bebe (Remix)',
#   'release_date': '2023-03-17',
#   'total_tracks': 2,
#   'url': 'https://open.spotify.com/album/6aBVGuOUEuX18rHxyDWbti'},
#  {'album_id': '0HiZ8fNXwJOQcrf5iflrdz',
#   'name': 'Endless Summer Vacation',
#   'release_date': '2023-03-10',
#   'total_tracks': 13,
#   'url': 'https://open.spotify.com/album/0HiZ8fNXwJOQcrf5iflrdz'},
#  {'album_id': '5letLUZIFsQikJYShfGNs4',
#   'name': 'The Beginning: Cupid',
#   'release_date': '2023-02-24',
#   'total_tracks': 3,
#   'url': 'https://open.spotify.com/album/5letLUZIFsQikJYShfGNs4'},
# ...

# %%
data['items'][0]
# Out:
# {'added_at': '2023-05-05T19:01:07Z',
#  'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#   'href': 'https://api.spotify.com/v1/users/',
#   'id': '',
#   'type': 'user',
#   'uri': 'spotify:user:'},
#  'is_local': False,
#  'primary_color': None,
#  'track': {'album': {'album_group': 'single',
#    'album_type': 'single',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6XkjpgcEsYab502Vr1bBeW'},
#      'href': 'https://api.spotify.com/v1/artists/6XkjpgcEsYab502Vr1bBeW',
#      'id': '6XkjpgcEsYab502Vr1bBeW',
#      'name': 'Grupo Frontera',
#      'type': 'artist',
#      'uri': 'spotify:artist:6XkjpgcEsYab502Vr1bBeW'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/4q3ewBCX7sLwd24euuV69X'},
#      'href': 'https://api.spotify.com/v1/artists/4q3ewBCX7sLwd24euuV69X',
#      'id': '4q3ewBCX7sLwd24euuV69X',
#      'name': 'Bad Bunny',
#      'type': 'artist',
# ...

# %%
artist_list = []
for row in data['items']:
    for key, value in row.items():
        if key == "track":
            for artist in value['artists']:
                artist_dict = {'artist_id':artist['id'], 'artist_name':artist['name'], 'external_url': artist['href']}
                artist_list.append(artist_dict)

# %%
artist_list
# Out:
# [{'artist_id': '6XkjpgcEsYab502Vr1bBeW',
#   'artist_name': 'Grupo Frontera',
#   'external_url': 'https://api.spotify.com/v1/artists/6XkjpgcEsYab502Vr1bBeW'},
#  {'artist_id': '4q3ewBCX7sLwd24euuV69X',
#   'artist_name': 'Bad Bunny',
#   'external_url': 'https://api.spotify.com/v1/artists/4q3ewBCX7sLwd24euuV69X'},
#  {'artist_id': '0XeEobZplHxzM9QzFQWLiR',
#   'artist_name': 'Eslabon Armado',
#   'external_url': 'https://api.spotify.com/v1/artists/0XeEobZplHxzM9QzFQWLiR'},
#  {'artist_id': '12GqGscKJx3aE4t07u7eVZ',
#   'artist_name': 'Peso Pluma',
#   'external_url': 'https://api.spotify.com/v1/artists/12GqGscKJx3aE4t07u7eVZ'},
#  {'artist_id': '1NNRWkhwmcXRimFYSBpB1y',
#   'artist_name': 'Yng Lvcas',
#   'external_url': 'https://api.spotify.com/v1/artists/1NNRWkhwmcXRimFYSBpB1y'},
#  {'artist_id': '12GqGscKJx3aE4t07u7eVZ',
#   'artist_name': 'Peso Pluma',
#   'external_url': 'https://api.spotify.com/v1/artists/12GqGscKJx3aE4t07u7eVZ'},
#  {'artist_id': '5YGY8feqx7naU7z4HrwZM6',
# ...

# %%
song_list = []
for row in data['items']:
    song_id = row['track']['id']
    song_name = row['track']['name']
    song_duration = row['track']['duration_ms']
    song_url = row['track']['external_urls']['spotify']
    song_popularity = row['track']['popularity']
    song_added = row['added_at']
    album_id = row['track']['album']['id']
    artist_id = row['track']['album']['artists'][0]['id']
    song_element = {'song_id':song_id,'song_name':song_name,'duration_ms':song_duration,'url':song_url,
                    'popularity':song_popularity,'song_added':song_added,'album_id':album_id,
                    'artist_id':artist_id
                   }
    song_list.append(song_element)

# %%
album_df = pd.DataFrame.from_dict(album_list)

# %%
album_df.head()
# Out:
#                  album_id                     name release_date  total_tracks  \
# 0  7aGzSSUD8S6IhPCsZSiuMT                un x100to   2023-04-17             1
# 1  5aDEezKnOqyQo0qvTFhpkM                DESVELADO   2023-04-28            16
# 2  6aBVGuOUEuX18rHxyDWbti          La Bebe (Remix)   2023-03-17             2
# 3  0HiZ8fNXwJOQcrf5iflrdz  Endless Summer Vacation   2023-03-10            13
# 4  5letLUZIFsQikJYShfGNs4     The Beginning: Cupid   2023-02-24             3
#
#                                                  url
# 0  https://open.spotify.com/album/7aGzSSUD8S6IhPC...
# 1  https://open.spotify.com/album/5aDEezKnOqyQo0q...
# 2  https://open.spotify.com/album/6aBVGuOUEuX18rH...
# 3  https://open.spotify.com/album/0HiZ8fNXwJOQcrf...
# 4  https://open.spotify.com/album/5letLUZIFsQikJY...

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   album_id      50 non-null     object
#  1   name          50 non-null     object
#  2   release_date  50 non-null     object
#  3   total_tracks  50 non-null     int64
#  4   url           50 non-null     object
# dtypes: int64(1), object(4)
# memory usage: 2.1+ KB

# %%
album_df = album_df.drop_duplicates(subset=['album_id'])

# %%
artist_df = pd.DataFrame.from_dict(artist_list)

# %%
artist_df = artist_df.drop_duplicates(subset=['artist_id'])

# %%
#Song Dataframe
song_df = pd.DataFrame.from_dict(song_list)

# %%
song_df.head()
# Out:
#                   song_id          song_name  duration_ms  \
# 0  6pD0ufEQq0xdHSsRbg9LBK          un x100to       194563
# 1  3qQbCzHBycnDpGskqOWY0E    Ella Baila Sola       165671
# 2  2UW7JaomAMuX9pZrjVpHAU    La Bebe - Remix       234352
# 3  4DHcnVTT87F0zZhRPYmZ3B            Flowers       200600
# 4  7FbrGaHYVDmfr7KoLIZnQ7  Cupid - Twin Ver.       174253
#
#                                                  url  popularity  \
# 0  https://open.spotify.com/track/6pD0ufEQq0xdHSs...          99
# 1  https://open.spotify.com/track/3qQbCzHBycnDpGs...          84
# 2  https://open.spotify.com/track/2UW7JaomAMuX9pZ...          98
# 3  https://open.spotify.com/track/4DHcnVTT87F0zZh...          90
# 4  https://open.spotify.com/track/7FbrGaHYVDmfr7K...          96
#
#              song_added                album_id               artist_id
# 0  2023-05-05T19:01:07Z  7aGzSSUD8S6IhPCsZSiuMT  6XkjpgcEsYab502Vr1bBeW
# 1  2023-05-05T19:01:07Z  5aDEezKnOqyQo0qvTFhpkM  0XeEobZplHxzM9QzFQWLiR
# ...

# %%
artist_df.head()
# Out:
#                 artist_id     artist_name  \
# 0  6XkjpgcEsYab502Vr1bBeW  Grupo Frontera
# 1  4q3ewBCX7sLwd24euuV69X       Bad Bunny
# 2  0XeEobZplHxzM9QzFQWLiR  Eslabon Armado
# 3  12GqGscKJx3aE4t07u7eVZ      Peso Pluma
# 4  1NNRWkhwmcXRimFYSBpB1y       Yng Lvcas
#
#                                         external_url
# 0  https://api.spotify.com/v1/artists/6XkjpgcEsYa...
# 1  https://api.spotify.com/v1/artists/4q3ewBCX7sL...
# 2  https://api.spotify.com/v1/artists/0XeEobZplHx...
# 3  https://api.spotify.com/v1/artists/12GqGscKJx3...
# 4  https://api.spotify.com/v1/artists/1NNRWkhwmcX...

# %%
album_df.head()
# Out:
#                  album_id                     name release_date  total_tracks  \
# 0  7aGzSSUD8S6IhPCsZSiuMT                un x100to   2023-04-17             1
# 1  5aDEezKnOqyQo0qvTFhpkM                DESVELADO   2023-04-28            16
# 2  6aBVGuOUEuX18rHxyDWbti          La Bebe (Remix)   2023-03-17             2
# 3  0HiZ8fNXwJOQcrf5iflrdz  Endless Summer Vacation   2023-03-10            13
# 4  5letLUZIFsQikJYShfGNs4     The Beginning: Cupid   2023-02-24             3
#
#                                                  url
# 0  https://open.spotify.com/album/7aGzSSUD8S6IhPC...
# 1  https://open.spotify.com/album/5aDEezKnOqyQo0q...
# 2  https://open.spotify.com/album/6aBVGuOUEuX18rH...
# 3  https://open.spotify.com/album/0HiZ8fNXwJOQcrf...
# 4  https://open.spotify.com/album/5letLUZIFsQikJY...

# %%
album_df['release_date'] = pd.to_datetime(album_df['release_date'])

# %%
song_df['song_added'] =  pd.to_datetime(song_df['song_added'])

# %%
song_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   song_id      50 non-null     object
#  1   song_name    50 non-null     object
#  2   duration_ms  50 non-null     int64
#  3   url          50 non-null     object
#  4   popularity   50 non-null     int64
#  5   song_added   50 non-null     datetime64[ns, UTC]
#  6   album_id     50 non-null     object
#  7   artist_id    50 non-null     object
# dtypes: datetime64[ns, UTC](1), int64(2), object(5)
# memory usage: 3.3+ KB
